# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.loc[4]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            36.7
# bill_depth_mm             19.3
# flipper_length_mm        193.0
# body_mass_g             3450.0
# sex                     Female
# Name: 4, dtype: object

# %%
df2 = df.sort_values(by='bill_depth_mm')
df2
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 244  Gentoo     Biscoe            42.9           13.1              215.0
# 220  Gentoo     Biscoe            46.1           13.2              211.0
# 268  Gentoo     Biscoe            44.9           13.3              213.0
# 228  Gentoo     Biscoe            43.3           13.4              209.0
# 236  Gentoo     Biscoe            42.0           13.5              210.0
# ..      ...        ...             ...            ...                ...
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 244       5000.0  Female
# 220       4500.0  Female
# ...

# %%
df2.loc[4]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            36.7
# bill_depth_mm             19.3
# flipper_length_mm        193.0
# body_mass_g             3450.0
# sex                     Female
# Name: 4, dtype: object

# %%
df2.iloc[4]
# Out:
# species              Gentoo
# island               Biscoe
# bill_length_mm         42.0
# bill_depth_mm          13.5
# flipper_length_mm     210.0
# body_mass_g          4150.0
# sex                  Female
# Name: 236, dtype: object

# %%
df[(df['species']=='Gentoo') & (df['sex']=='Female')]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 225  Gentoo  Biscoe            46.5           13.5              210.0
# 226  Gentoo  Biscoe            45.4           14.6              211.0
# 228  Gentoo  Biscoe            43.3           13.4              209.0
# 230  Gentoo  Biscoe            40.9           13.7              214.0
# 232  Gentoo  Biscoe            45.5           13.7              214.0
# 234  Gentoo  Biscoe            45.8           14.6              210.0
# 236  Gentoo  Biscoe            42.0           13.5              210.0
# 238  Gentoo  Biscoe            46.2           14.5              209.0
# 241  Gentoo  Biscoe            45.1           14.5              215.0
# 242  Gentoo  Biscoe            46.5           14.5              213.0
# ...

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
for s in ['Adelie', 'Chinstrap', 'Gentoo']:
    plt.scatter(df[df['species']==s].bill_length_mm, df[df['species']==s].bill_depth_mm)

# %%
df.groupby(by='species')

# %%
for n, g in df.groupby(by='species'):
    plt.scatter(g['bill_length_mm'], g['bill_depth_mm'])

# %%
df.to_csv('penguins.csv', index=False)

# %%
sns.boxenplot(data=df, x='species', y='body_mass_g', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.violinplot(data=df, x='species', y='body_mass_g', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=df, x='species', y='body_mass_g', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>
